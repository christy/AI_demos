# %% [markdown]
# ## Galileo Getting Started
#
# **Directions:**  From your console, create a new project, follow directions on your screen.
# https://console.acme.rungalileo.io/new-project?projectId=4b506a5d-eb3c-44fb-9e04-d41ee1662c18&taskType=8
#
# **Another quick start tutorial**:  https://docs.rungalileo.io/galileo/gen-ai-studio-products/galileo-evaluate/quickstart
#
#
# **Installation bugs:** <br>
#
# 🐞 BUG#1:  As of Nov 2024, Galileo does not work on Python 3.12.
# > ModuleNotFoundError: No module named 'imp' <br>
# > you should use importlib instead of imp module. Update to python 3.11 => imp python 3.12+ ==> importlib
#
# Solution: Only use Python 3.11 kernels with Galileo for now!
#
# 🐞 BUG#2: Rust is required, before installing Galileo.<br>
# Solution:  Install it through the system's package manager or via https://rustup.rs/
#
# 🐞 BUG#3: vaex is required to run cpp kernels inside pyenv without conda. <br>
# - google search mac M1 python Failed to build vaex-core
# - https://github.com/vaexio/vaex/issues/1903
# - https://github.com/vaexio/vaex/issues/2366

# %%
# !python --version
# Out:
# Python 3.11.9

# %%
# Broken!!
# !python -m pip install vaex
# !python -m pip install dataquality 
# !python -m pip install promptquality
# Out:
# ...
#   Using cached vaex-4.17.0-py3-none-any.whl.metadata (6.0 kB)
# ...
#   Using cached vaex-core-4.17.1.tar.gz (2.5 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached vaex_astro-0.9.3-py3-none-any.whl.metadata (345 bytes)
# ...
#   Using cached vaex_hdf5-0.14.1-py3-none-any.whl.metadata (321 bytes)
# ...
#   Using cached vaex_viz-0.5.4-py3-none-any.whl.metadata (345 bytes)
# ...
#   Using cached vaex_server-0.9.0-py3-none-any.whl.metadata (430 bytes)
# ...
#   Using cached vaex_jupyter-0.8.2-py3-none-any.whl.metadata (517 bytes)
# ...
#   Using cached vaex_ml-0.18.3-py3-none-any.whl.metadata (485 bytes)
# ...
#   Using cached astropy-6.1.6-cp311-cp311-macosx_11_0_arm64.whl.metadata (10 kB)
# ...
#   Using cached numpy-2.1.3-cp311-cp311-macosx_14_0_arm64.whl.metadata (62 kB)
# ...
#   Using cached aplus-0.11.0-py3-none-any.whl
# ...
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# ...

# %%
import dataquality as dq

dq.init(task_type="text_classification",
        project_name="glamorous_gray_hornet",
        run_name="run_1")

# %%
# Props to Sebastian Raschka for this handy watermark.
# !python -m pip install watermark
# %load_ext watermark

# %watermark -a 'Christy Bergman' -v -p vaex,dataquality,promptquality --conda
# Out:
# Author: Christy Bergman
#
# Python implementation: CPython
# Python version       : 3.11.9
# IPython version      : 8.29.0
#
# vaex         : not installed
# dataquality  : not installed
# promptquality: not installed
#
# conda environment: n/a
